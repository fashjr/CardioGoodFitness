# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from pandas import DataFrame

# %%
data = pd.read_csv("CardioGoodFitness.csv")

# %%
data.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
#showing how many rows and columns are in the dataset
data.shape
# Out:
# (180, 9)

# %%
#to check the datatype of each column
#to also check if there is any missing value in the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#to check the minimum income
data['Income'].min()
# Out:
# 29562

# %%
#to check the maximum income
data['Income'].max()
# Out:
# 104581

# %%
#to check the minimum miles
data['Miles'].min()
# Out:
# 21

# %%
#to check the maxmum miles
data['Miles'].max()
# Out:
# 360

# %%
#to find the average fitness of customers
data['Fitness'].mean()
# Out:
# 3.311111111111111

# %%
#to find the middle fitness
data['Fitness'].median()
# Out:
# 3.0

# %%
#to find the middle usage
data['Usage'].median()
# Out:
# 3.0

# %%
#to find the average education of customers
data['Education'].mean()
# Out:
# 15.572222222222223

# %%
#to find the middle Education
data['Education'].median()
# Out:
# 16.0

# %%
#to find the average income of customers
data['Income'].mean()
# Out:
# 53719.57777777778

# %%
#to find the middle income
data['Income'].median()
# Out:
# 50596.5

# %%
#to find the average miles of customers
data['Miles'].mean()
# Out:
# 103.19444444444444

# %%
#to find the middle miles
data['Miles'].median()
# Out:
# 94.0

# %%
#to find the average age of customers
data['Age'].mean()
# Out:
# 28.788888888888888

# %%
#to find the middle age
data['Age'].median()
# Out:
# 26.0

# %%
#no of unique values present in product
data['Product'].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
#no of values of each product
data['Product'].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
#no of values of each product
data['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
#no of values of each marital status
data['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
#to find the average age of each gender
data.groupby(['Gender'])['Age'].mean()
# Out:
# Gender
# Female    28.565789
# Male      28.951923
# Name: Age, dtype: float64

# %%
data.groupby(['Gender'])['Age'].median()
# Out:
# Gender
# Female    26.5
# Male      26.0
# Name: Age, dtype: float64

# %%
#to find the average income of each gender
data.groupby(['Gender'])['Income'].mean()
# Out:
# Gender
# Female    49828.907895
# Male      56562.759615
# Name: Income, dtype: float64

# %%
data.groupby(['Gender'])['Income'].median()
# Out:
# Gender
# Female    47754.0
# Male      52302.0
# Name: Income, dtype: float64

# %%
#to find the average miles of each gender
data.groupby(['Gender'])['Miles'].mean()
# Out:
# Gender
# Female     90.013158
# Male      112.826923
# Name: Miles, dtype: float64

# %%
data.groupby(['Gender'])['Miles'].median()
# Out:
# Gender
# Female     85.0
# Male      100.0
# Name: Miles, dtype: float64

# %%
#to calculate the relationship between each column
data.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
#Hist showing the frequency of ages of those who buy treadmills
plt.title('Histogram: age')
plt.xlabel('ages')
plt.ylabel('Frequency')
sns.histplot(data, x='Age', color='purple');

# %%
#Hist showing the frequency of ages of those who buy treadmills with the kde
plt.title('Histogram: age')
plt.xlabel('ages')
plt.ylabel('Frequency')
sns.histplot(data, x='Age', kde=True);

# %%
plt.title('Histogram: age')
plt.xlabel('ages')
plt.ylabel('Frequency')
sns.histplot(data, x='Age', kde=True, bins=6);

# %%
#Hist showing the marital status of customers
plt.title('Histogram: Marital status')
plt.xlabel('status')
plt.ylabel('Frequency')
sns.histplot(data, x='MaritalStatus', color='red');

# %%
#Hist showing the education (in years) of those who buy treadmills
plt.title('Histogram: level of education')
plt.xlabel('education')
plt.ylabel('Frequency')
plt.xlim(12,22)
sns.histplot(data, x='Education');

# %%
#histogram showing the average usage of the treadmills
plt.title('Histogram: Usage')
plt.xlabel('usage')
plt.ylabel('Frequency')
sns.histplot(data=data, x='Usage');

# %%
#scatterplot showing the relationship between the income and ages of customers
plt.figure(figsize=(10,5))
sns.scatterplot(data=data, x='Age', y='Income');

# %%
#scatterplot showing the relationship between the income, ages and products used by customers
#shows us people with higher income purchase TM798
plt.figure(figsize=(10,5))
sns.scatterplot(data=data, x='Age', y='Income', hue='Product');

# %%
#lineplot showing the relationship between the income, ages and products used by customers
plt.figure(figsize=(10,5))
sns.lineplot(data=data, x='Age', y='Income', hue='Product');

# %%
#boxplot indicating income is rightly skewed and has alot of outliers
sns.boxplot(data=data, x='Income');

# %%
#shows the interquartile relationship between the genders and their income
#boxplot indicating income is rightly skewed and has outliers
sns.boxplot(data=data, x='Income', y='Gender');

# %%
#shows the interquartile relationship between the genders and their ages
#both genders are rightly skewed and female has outlier
sns.boxplot(data=data, x='Age', y='Gender');

# %%
#pairplot to plot pairwise relationships between variables
sns.pairplot(data=data);

# %%
#scatterplot showing the relationship between the income and ages of both genders
sns.scatterplot(data=data, x='Income', y='Age', hue='Gender');

# %%
#to calculate the relationship between every variable 
#each column represented using colour encoded matrix
sns.heatmap(data.corr(), annot = True, cmap='YlGnBu');

# %%
#boxplot showing Age is rightly skewed, outlier, IQR, Q1, Q3
plt.figure(figsize=(10,5))
sns.boxplot(data=data, x='Age');

# %%
#boxplot showing income outlier,IQR, Q1, Q3
plt.figure(figsize=(10,5))
sns.boxplot(data=data, x='Income');

# %%
#boxplot showing miles is rightly skewed and has outliers
plt.figure(figsize=(10,5))
sns.boxplot(data=data, x='Miles');

# %%
#showing the frequency of customers using each product
sns.countplot(data=data, x='Product');

# %%
#Showing the counts of marital status based on the product
sns.countplot(data=data, x='MaritalStatus', hue='Product');

# %%
#Showing the counts of marital status based on fitness
sns.countplot(data=data, x='MaritalStatus', hue='Fitness');

# %%
#Showing the counts of product based on genders.
sns.countplot(data=data, x='Product', hue='Gender');

# %%
#Showing the counts of product based on marital status
sns.countplot(data=data, x='Product', hue='MaritalStatus');

# %%
#Showing the counts of usage based on marital status
sns.countplot(data=data, x='Usage', hue='MaritalStatus');

# %%
#Showing the counts usage based on product
sns.countplot(data=data, x='Usage', hue='Product');

# %% [markdown]
# KEY INSIGHT/ OBSERVATION

# %% [markdown]
# Miles is highly correlated to usage, income and fitness
# Treadmills are bought mostly by married people,
# TM195 is the most bought and TM798 is the least bought by customers,
# TM798 is bought by individuals with high usage and mostly males,
# Products are mostly bought by people in the age range of 24-27,
# The average usage of customers is 3 days per week,
# the mean age of customers is 29, the age of customers who buy the most is 25,
# TM798 is bought by people with lesser age and higher income.

# %% [markdown]
# RECOMMENDATION

# %% [markdown]
# Recommend TM498 to people who have high usage and average income,
# Recommend TM195 to people with low usage and low income,
# Recommend TM798 to people with very high income, and high usage.
